# %%
import pickle

# %%
cluster = pickle.load(open('Week7a_2_cluster.pkl', 'rb'))

# %%
##### Part number is keys #####
cluster.keys()
# Out:
# [u'1', u'2']

# %%
##### Matching sub-expression as key in each part #####
cluster['2'].keys()
# Out:
# ['Nothing',
#  "[('R', 0.038549681070836672, u'Q(1.76777)', u'Q(1.76777)')]",
#  "[('R.0', 1.76777, u'1.76777', u'1.76777')]"]

# %%
##### All attempts as value #####
cluster['2']['Nothing']
# Out:
# [u'no',
#  u'0.039',
#  u'0.25',
#  u'0.039',
#  u'0.039',
#  u'Q((50/200-.2)/(.2*.8/200)^1/2)',
#  u'yes',
#  u'no',
#  u'no',
#  u'no',
#  u'no',
#  u'no',
#  u'0.039',
#  u'0.20',
#  u'0.25',
#  u'no',
#  u'Yes',
#  u'No',
#  u'0.8',
#  u'no',
#  u'no',
#  u'Q((50/200 - .2)/sqrts(.2(1-.2)/200))',
#  u'no',
#  u'.039',
#  u'0.039',
#  u'no',
#  u'0.039',
#  u'P ( Z>1.7677)',
#  u'Z>1.7677',
#  u'0.039',
#  u'0.04',
#  u'0.039',
#  u'1%',
#  u'1',
#  u'3',
#  u'Q((50-200(.2))/(sqrt(200*.2)))',
#  u'Q(0.5/sqrt(0.16/200))',
#  u'Q(2*$phi-1)',
#  u'yes',
#  u'no',
#  u'.039',
#  u'P(H>(.25-.2)/sqrt((.2)*(1-.2)/200))',
#  u'H>(.25-.2)/sqrt((.2)*(1-.2)/200)',
#  u'.039',
#  u'.05',
#  u'.2',
#  u'Q((.25-.2)/((.16/200)^(1/2))',
#  u'Q(0.25-0.2)/(sqrt(0.2 * ( 1 - 0.2 ) / 200 ))',
#  u'no',
#  u'yes',
#  u'no',
#  u'.039',
#  u'1.7678',
#  u'.2',
#  u'.039*2',
#  u'Q(10/sqrt(40))',
#  u'yes',
#  u'yes',
#  u'no',
#  u'no',
#  u'yes',
#  u'yes',
#  u'yes',
#  u'yes',
#  u'0.039',
#  u'yes',
#  u'no',
#  u'no',
#  u'0.039',
#  u'Q((200*.2-50)/(sqrt(200*.2(1-.2))))',
#  u'Q(0.3125)',
#  u'no',
#  u'yes',
#  u'no',
#  u'0.039',
#  u'P(Z>1.7678)',
#  u'0.039',
#  u'0',
#  u'Q(',
#  u'Q(-10/sqrt(32))',
#  u'no',
#  u'yes',
#  u'Q(0.052579672)',
#  u'0.039',
#  u'.961',
#  u'.39',
#  u'.039',
#  u'Q(0.052579672)0.041399332',
#  u'0.0771',
#  u'0.038',
#  u'0.030',
#  u'0.031',
#  u'0.032',
#  u'0.033',
#  u'Q()',
#  u'Q(.2)',
#  u'1 - [(0.25 - 0.2)/(0.2(1 - 0.2))^0.5]',
#  u'1 - [(50/200) - 0.2]/[(0.2) * (1 - 0.2)/200]^0.5',
#  u'Q(1/4)',
#  u'Q([50-0.2*200]/[.2 * .8 * 200])',
#  u'Q(.2)',
#  u'1.7678',
#  u'0.039',
#  u'.0392',
#  u'1.96',
#  u'1.98',
#  u'0.9687',
#  u'.0784',
#  u'No',
#  u'no',
#  u'yes',
#  u'Q(8)',
#  u'yes',
#  u'Q(.5)',
#  u'no',
#  u'Q(1.58)',
#  u'Q((50-200/5)/sqrt(0.2*0.8))',
#  u'Q((50-200*0.2)/sqrt(0.2*200))',
#  u'Q((50-200*0.2)/sqrt(0.2*200))*0.8*',
#  u'.674',
#  u'.9616',
#  u'Q(200*0.2)',
#  u'0.2',
#  u'Q(((50/200) - .20) / (.20(1 - .20)200))',
#  u'1-Q((50-200*.2)/(sqrt(200*0.2*0.8)))',
#  u'1-(1/2+1/2erf((1-(1/2+1/2erf(.3/sqrt(2))))/sqrt(2)))',
#  u'Q(1-(1/2+1/2erf(.3/sqrt(2))))',
#  u'yes',
#  u'no',
#  u'no',
#  u'yes',
#  u'yes',
#  u'yes',
#  u'no',
#  u'no',
#  u'.039',
#  u'1.76',
#  u'.020',
#  u'.39',
#  u'.039',
#  u'no',
#  u'Q(1.76)',
#  u'q((.25-.20)/sqrt((.2(1-.2))/200))',
#  u'no',
#  u'Q((40 - 50)/sqrt(40*.8))',
#  u'1 - Q(10/(200*0.2*0.8)^0.5)',
#  u'Q(1.776953)',
#  u'1-Q(1.776953)',
#  u'.2',
#  u'Q(1.776953)',
#  u'2*Q(1.776953)',
#  u'no',
#  u'no',
#  u'.16/200',
#  u'Q(.05/sqrt(.16/200)',
#  u'0.392',
#  u'0.0392',
#  u'0.039',
#  u'no',
#  u'no',
#  u'no',
#  u'0.039',
#  u'0.04',
#  u'.2',
#  u'1/5',
#  u'.20',
#  u'.25',
#  u'0.05',
#  u'0.039',
#  u'0.20',
#  u'0.039',
#  u'Q(8/sqrt(2))',
#  u'Q(0.1/sqrt(0.1*0.9/40))',
#  u'Q(2/sqrt(2))',
#  u'.039',
#  u'0.039',
#  u'P(Z > 1.7678)',
#  u'(Q > 1.7678)',
#  u'.2322',
#  u'.7322',
#  u'0.0771',
#  u'0.1542',
#  u'0.0104',
#  u'no',
#  u'0.039',
#  u'Q(0.2)',
#  u'Q(0.25)',
#  u'1- Phi(0.2)',
#  u'1- Phi(0.25)',
#  u'Q(0.05/sqrt(0.16/200)',
#  u'no',
#  u'q((0.25-.2)/sqrt(0.2(1-0.2)/200))',
#  u'yes',
#  u'no',
#  u'No',
#  u'no',
#  u'.039',
#  u'50/200',
#  u'0.039',
#  u'0.0390',
#  u'0.0391',
#  u'0.0392',
#  u'0.0393',
#  u'0.0394',
#  u'0.0395',
#  u'0.0396',
#  u'0.0397',
#  u'0.0398',
#  u'0.0399',
#  u'.2',
#  u'Q(((0.2*200)-5)/sqrt(200*0.2(1-0.2)))',
#  u'Q(1.632993162)',
#  u'0.2',
#  u'.04',
#  u'1-Q(1.767766953',
#  u'1-Q(1.767766953)',
#  u'1-Q((0.25-0.2) /((0.2)(1-0.2)/200)^(1/2))',
#  u'.2',
#  u'Q(200)',
#  u'Q(150)',
#  u'Q(.2)',
#  u'Q(40)',
#  u'.025',
#  u'Q(.2)',
#  u'0.039',
#  u'0',
#  u'.05',
#  u'5',
#  u'.01',
#  u'Q(1.21)',
#  u'0.07841',
#  u'0.07673',
#  u'0.9599',
#  u'0.9608',
#  u'0.9616',
#  u'.039',
#  u'.077',
#  u'0.038556.',
#  u'yes',
#  u'no',
#  u'P[.2>(50-40)/(sqrt((200)(.2)(.8)))]',
#  u'[.2>(50-40)/(sqrt((200)(.2)(.8)))]',
#  u'.2',
#  u'[ [(200 )(.2 )]-(.2 ) ]/[ sqrt[(200 )(.2 ) (1 -.2 )]]',
#  u'[ [(50 )(.2 )]-(.2 ) ]/[ sqrt[(200 )(.2 ) (1 -.2 )]]',
#  u'no',
#  u'.2',
#  u'-.2608',
#  u'.2608',
#  u'.25',
#  u'10Q/sqrt(32)',
#  u'(10Q)/sqrt(32)',
#  u'(10q)/sqrt(32)',
#  u'(10*.2)/sqrt(32)',
#  u'yes',
#  u'5%',
#  u'0.039',
#  u'0.03',
#  u'0.02',
#  u'0.04',
#  u'Q(0.3)',
#  u'Q(0.31)',
#  u'Q(0.29)',
#  u'Q(0.299)',
#  u'Q(0.2999999)',
#  u'Q(0.33)',
#  u'Q(0.28)',
#  u'Q(0.26)',
#  u'Q(0.279)',
#  u'Q(1.8)',
#  u'Q(1.89)',
#  u'Q(1.79)',
#  u'Q(1.6)',
#  u'Q(1.799999)',
#  u'Q(0.883883476)',
#  u'Q(.2)',
#  u'1-Q(.2)',
#  u'2*Q(.2)',
#  u'.15',
#  u'.025',
#  u'.0015',
#  u'.0003',
#  u'1',
#  u'2',
#  u'3',
#  u'4',
#  u'0.04935333238',
#  u'(Q(50-40)/(32^(1/2)))',
#  u'Q(10/(4*sqrt(0.2*0.8*200)))',
#  u'Q(1)',
#  u'Q(2)',
#  u'Q(3)',
#  u'Q(4)',
#  u'Q(.2)',
#  u'Q(50)',
#  u'Q(1)',
#  u'Q(0.5/sqrt(0.16/200))',
#  u'Q(0.5/sqrt(0.20/200))',
#  u'Q(0.05/sqrt(0.20/200))',
#  u'Q(50-40)/sqrt(32)',
#  u'Q(50-40/sqrt(32))',
#  u'0.077',
#  u'0.077099',
#  u'yes',
#  u'no',
#  u'q ((.25 - .2) / sqrt( (.2 * .8 ) / 200) )',
#  u'Q((.25-.2)/(sqrt(.16/200)),1.7677)',
#  u'0.039',
#  u'P(Z > 1.7678)',
#  u'Q(Z > 1.7678)',
#  u'20',
#  u'yes',
#  u'yes',
#  u'sqrt((1/5)(200)(1-(1/5))',
#  u'sqrt((1/5)(200)(1-(1/5)))',
#  u'Q()',
#  u'Q(.25)',
#  u' 0.039.',
#  u' 0.039',
#  u'yes']
